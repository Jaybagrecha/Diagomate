# %%
# Create A machine learning model for a disease dataset - Diabetes, and create a website where you can input all
#the variables and it will give result if patient has diabetes or not.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
import seaborn as sbn
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier

df = pd.read_csv(r"diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().values.any()
# Out:
# False

# %%
df["Outcome"].value_counts().plot.barh()
df["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e87ec_row0_col0, #T_e87ec_row1_col1, #T_e87ec_row2_col2, #T_e87ec_row3_col3, #T_e87ec_row4_col4, #T_e87ec_row5_col5, #T_e87ec_row6_col6, #T_e87ec_row7_col7, #T_e87ec_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e87ec_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_e87ec_row0_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e87ec_row0_col3, #T_e87ec_row7_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e87ec_row0_col4, #T_e87ec_row0_col5, #T_e87ec_row0_col6, #T_e87ec_row2_col8, #T_e87ec_row3_col0, #T_e87ec_row3_col1, #T_e87ec_row3_col7, #T_e87ec_row6_col2, #T_e87ec_row7_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e87ec_row0_col7 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_e87ec_row0_col8, #T_e87ec_row1_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e87ec_row1_col0 {
#   background-color: #799cf8;
# ...

# %%
y = df["Outcome"]
X = df.drop(["Outcome"], axis= 1)
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.70,random_state=101)

# %%
loj = linear_model.LogisticRegression(solver= "liblinear")
loj_model = loj.fit(X_train, y_train)
loj_model
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_pred = loj_model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7835497835497836

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.84       150
#            1       0.76      0.56      0.64        81
#
#     accuracy                           0.78       231
#    macro avg       0.78      0.73      0.74       231
# weighted avg       0.78      0.78      0.77       231

# %%
mat = confusion_matrix(y_test, y_pred)
p = sbn.heatmap(pd.DataFrame(mat), annot=True, cmap="YlGnBu" ,fmt='g')

# %%
rf_model = RandomForestClassifier().fit(X_train, y_train)
rf_model
# Out:
# RandomForestClassifier()

# %%
y_pred = rf_model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.7705627705627706

# %%
Importance = pd.DataFrame({"Importance": rf_model.feature_importances_*100},
                          index = X_train.columns)

Importance.sort_values(by = "Importance",
                       axis = 0,
                       ascending = True).plot(kind = "barh", color = "blue")

plt.xlabel("Variables Importance Ratio")
# Out:
# Text(0.5, 0, 'Variables Importance Ratio')

# %%
import pickle
pickle.dump(loj, open('model_diabetes.pkl','wb'))
